# %% [markdown]
# # AUROC

# %%
import numpy as np
from sklearn.metrics import roc_curve, roc_auc_score

# %%
np.random.uniform(0.9 , 1)
# Out:
# 0.9547412117893871

# %%
y_true = np.array(95*[1] + 5*[0])
y_pred = np.random.uniform(low=0.9, high=1, size=100)

# %%
fpr, tpr, thresholds = roc_curve(y_true=y_true, y_score=y_pred)

print(f"True Positive Rate: {tpr}")
print(f"False Positive Rate: {fpr}")
print(f"thresholds: {thresholds}")
# Out:
# True Positive Rate: [0.         0.01052632 0.07368421 0.07368421 0.41052632 0.41052632
#  0.58947368 0.58947368 0.62105263 0.62105263 0.90526316 0.90526316
#  1.        ]
# False Positive Rate: [0.  0.  0.  0.2 0.2 0.4 0.4 0.6 0.6 0.8 0.8 1.  1. ]
# thresholds: [1.99848896 0.99848896 0.99448351 0.99409768 0.96142377 0.95816517
#  0.94499507 0.94339293 0.94056659 0.94018555 0.90882841 0.90820753
#  0.90043007]

# %%
roc_auc_score(y_true, y_pred)
# Out:
# 0.52

# %%
import matplotlib.pyplot as plt

from sklearn.metrics import roc_curve, auc

plt.figure()
lw = 2
plt.plot(
    fpr[2],
    tpr[2],
    color="darkorange",
    lw=lw,
    label="ROC curve (area = %0.2f)" % roc_auc[2],
)
plt.plot([0, 1], [0, 1], color="navy", lw=lw, linestyle="--")
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Receiver operating characteristic example")
plt.legend(loc="lower right")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-2919f7a382ff> in <module>()
#      10     color="darkorange",
#      11     lw=lw,
# ---> 12     label="ROC curve (area = %0.2f)" % roc_auc[2],
#      13 )
#      14 plt.plot([0, 1], [0, 1], color="navy", lw=lw, linestyle="--")
#
# NameError: name 'roc_auc' is not defined
