# %% [markdown]
# ref: https://docs.python.org/3/library/random.html

# %%
import random

# %%
random.seed(2)

# Return a randomly selected element from `range(start, stop, step)`
random.randrange(1, 10, 1)  # so stop is not included

# alias of random.randrange(a, b+1)
random.randint(1, 10)
# Out:
# 2

# %%
# Return the next random floating point number in the range [0.0, 1.0).
random.random()
# Out:
# 0.6697304014402209

# %%
# return a random element from non-empty sequence
random.choice(range(10))
# Out:
# 1

# %%
random.choice('computer')
# Out:
# 'u'

# %%
mylist = ["apple", "banana", "cherry"]

print(random.choices(mylist, weights = [10, 1, 1], k = 14))

# %%
# Return a k sized list of elements chosen from the population with replacement
random.choices(["123", "456"], weights=[5, 5], k=2)
# Out:
# ['456', '123']

# %%
# Return a k length list of unique elements chosen from the population sequence or set. Used for random sampling without replacement.
random.sample(["123", "456", "789", "000"], k=2)
# Out:
# ['456', '000']
